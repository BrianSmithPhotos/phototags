# %%
import exiftool

files = ["../Research/a.jpg", "../Research/b.raf", "../Research/c.tif", "../Research/d.orf", "../Research/e.dng"]
with exiftool.ExifToolHelper() as et:
    metadata = et.get_metadata(files)
for d in metadata:
    print("{:20.20} {:20.20}".format(d["SourceFile"],
                                     d["EXIF:DateTimeOriginal"]))
# Out:
# ../Research/a.jpg    2026:05:20 07:22:42
# ../Research/b.raf    2022:05:17 09:11:05
# ../Research/c.tif    2024:12:08 15:06:42
# ../Research/d.orf    2026:05:20 07:33:03
# ../Research/e.dng    2024:12:08 15:06:42
